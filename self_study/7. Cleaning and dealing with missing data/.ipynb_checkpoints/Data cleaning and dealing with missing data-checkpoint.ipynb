# %% [markdown]
# # Dealing with missing values

# %%
import pandas as pd
import missingno as msno

# %%
# missingNumber helps visualize missing values in a nice way

# %%
df = pd.read_csv("../data/housing.csv")

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
# using quilt to look at missing datas

# %%
# import numpy as np
# collisions = collision.replace('nan', np.nam) // replaces nan value 
# 
# pd.read_csv("", na_values=["nan", -999.25]) // so you know its a missing value

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# we can look for missing value as well as get numeric value

# %%
df["total_bedrooms_corrected"] = df["total_bedrooms"] # copy
df["total_bedrooms_corrected"].fillna(df["total_bedrooms"].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# longitude                     0
# latitude                      0
# housing_median_age            0
# total_rooms                   0
# total_bedrooms              207
# population                    0
# households                    0
# median_income                 0
# median_house_value            0
# ocean_proximity               0
# total_bedrooms_corrected      0
# dtype: int64

# %%
# looking at values differences and replacing nans with numeric value

# %%
df[["total_bedrooms_corrected", "total_bedrooms"]].head(50)
# Out:
#     total_bedrooms_corrected  total_bedrooms
# 0                      129.0           129.0
# 1                     1106.0          1106.0
# 2                      190.0           190.0
# 3                      235.0           235.0
# 4                      280.0           280.0
# 5                      213.0           213.0
# 6                      489.0           489.0
# 7                      687.0           687.0
# 8                      665.0           665.0
# 9                      707.0           707.0
# 10                     434.0           434.0
# 11                     752.0           752.0
# 12                     474.0           474.0
# 13                     191.0           191.0
# 14                     626.0           626.0
# 15                     283.0           283.0
# 16                     347.0           347.0
# 17                     293.0           293.0
# 18                     455.0           455.0
# 19                     298.0           298.0
# ...
