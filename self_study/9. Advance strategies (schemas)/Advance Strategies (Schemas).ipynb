# %% [markdown]
# #  Advance strategies ( Schemas )

# %% [markdown]
# validating data to be within certain ranges in an advanced strategy when automating data science processes.

# %%
pip install pandera
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandera in c:\users\dikhw\appdata\roaming\python\python39\site-packages (0.13.4)
# Requirement already satisfied: pandas>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from pandera) (1.4.4)
# Requirement already satisfied: pydantic in c:\users\dikhw\appdata\roaming\python\python39\site-packages (from pandera) (1.10.6)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from pandera) (21.3)
# Requirement already satisfied: typing-inspect>=0.6.0 in c:\users\dikhw\appdata\roaming\python\python39\site-packages (from pandera) (0.8.0)
# Requirement already satisfied: wrapt in c:\programdata\anaconda3\lib\site-packages (from pandera) (1.14.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from pandera) (1.21.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->pandera) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.2.0->pandera) (2022.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.6.0->pandera) (4.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from typing-inspect>=0.6.0->pandera) (0.4.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pandera) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv("../data/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# schema is our rule set about how our dataframe is supposed to look like

# %%
schema = pa.DataFrameSchema({"ocean_proximity": pa.Column(pa.String)})
schema.validate(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
schema = pa.DataFrameSchema({"ocean_proximity": pa.Column(pa.String,
                                                         pa.Check.isin(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND']))})

# %%
schema.validate(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# validating helps data consistancy for best output and avoid future errors

# we can check validations for other colums as well. i.e. (total rooms)

# %%
import numpy as np
df = pd.read_csv("../data/housing.csv", dtype={"total_rooms" : np.int64})

schema = pa.DataFrameSchema({"ocean_proximity": pa.Column(pa.String,
                                                         pa.Check.isin(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'])),
                            "total_rooms": pa.Column(pa.Int),
                            "housing_median_age": pa.Column(pa.Float, pa.Check(lambda n: n**2 > 0))
                            })

schema.validate(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                52.0         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# # Reason why we should validate data

# %%
df_simple = pd.DataFrame({"percentages": [0.1,0.3,25.3,4.1,0.21,98]})

schema = pa.DataFrameSchema({"percentages" : pa.Column(pa.Float,
                                                      pa.Check.less_than_or_equal_to(1))})

schema.validate(df_simple)
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2356\2524025599.py in <module>
#       4                                                       pa.Check.less_than_or_equal_to(1))})
#       5
# ----> 6 schema.validate(df_simple)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     532             return check_obj.pandera.add_schema(self)
#     533
# --> 534         return self._validate(
#     535             check_obj=check_obj,
#     536             head=head,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     730                 check_results.append(check_utils.is_table(result))
#     731             except errors.SchemaError as err:
# --> 732                 error_handler.collect_error("schema_component_check", err)
#     733             except errors.SchemaErrors as err:
#     734                 for schema_error_dict in err.schema_errors:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in _validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     722         for schema_component in schema_components:
#     723             try:
# --> 724                 result = schema_component(
#     725                     df_to_validate,
#     726                     lazy=lazy,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in __call__(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2136     ) -> Union[pd.DataFrame, pd.Series]:
#    2137         """Alias for ``validate`` method."""
# -> 2138         return self.validate(
#    2139             check_obj, head, tail, sample, random_state, lazy, inplace
#    2140         )
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schema_components.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#     221                     )
#     222             else:
# --> 223                 validate_column(check_obj, column_name)
#     224
#     225         return check_obj
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schema_components.py in validate_column(check_obj, column_name)
#     194
#     195         def validate_column(check_obj, column_name):
# --> 196             super(Column, copy(self).set_name(column_name)).validate(
#     197                 check_obj,
#     198                 head,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2094                 )
#    2095             except errors.SchemaError as err:
# -> 2096                 error_handler.collect_error("dataframe_check", err)
#    2097             except Exception as err:  # pylint: disable=broad-except
#    2098                 # catch other exceptions that may occur when executing the
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\error_handlers.py in collect_error(self, reason_code, schema_error, original_exc)
#      30         """
#      31         if not self._lazy:
# ---> 32             raise schema_error from original_exc
#      33
#      34         # delete data of validated object from SchemaError object to prevent
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in validate(self, check_obj, head, tail, sample, random_state, lazy, inplace)
#    2089             try:
#    2090                 check_results.append(
# -> 2091                     _handle_check_results(
#    2092                         self, check_index, check, check_obj, *check_args
#    2093                     )
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandera\schemas.py in _handle_check_results(schema, check_index, check, check_obj, *check_args)
#    2480             warnings.warn(error_msg, UserWarning)
#    2481             return True
# -> 2482         raise errors.SchemaError(
#    2483             schema,
#    2484             check_obj,
#
# SchemaError: <Schema Column(name=percentages, type=DataType(float64))> failed element-wise validator 0:
# <Check less_than_or_equal_to: less_than_or_equal_to(1)>
# failure cases:
#    index  failure_case
# 0      2          25.3
# 1      3           4.1
# 2      5          98.0

# %%
# we can see the error with the error message

# now we can deal with the error

# %%
df_simple = pd.DataFrame({"percentages": [0.1,0.3,25.3,4.1,0.21,98]})

df_simple.percentages[df_simple.percentages>1] /= 100
schema = pa.DataFrameSchema({"percentages" : pa.Column(pa.Float,
                                                      pa.Check.less_than_or_equal_to(1))})

schema.validate(df_simple)
# Out:
#    percentages
# 0        0.100
# 1        0.300
# 2        0.253
# 3        0.041
# 4        0.210
# 5        0.980

# %%
# in this study, we looked at different schemas and how we can validate data in the beginning
